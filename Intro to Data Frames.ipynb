# %%
#pandas : veri bilimi:
#network, db, web, mobil,
#get,put,post,delete
#raw: ham data
#datanin icinden bilgi cekmektir. structure data
#veri biliminin amaci datadan katma degerli bilgi cikarmaktir.

# %% [raw]
# !pip install openpyxl --upgrade

# %% [raw]
# !pip install pandas

# %%
#DF: Data Frame: Veri Tablosu
#json, yaml, sql, oracle, txt, python, xlsx, xls, csv, html, text...

# %%
#pandas ve json kutuphanelerini import et
import pandas as pd
import json

# %%
#AI1.json

# %%
AI1=[{'Technology': 'NA', 'Library': 'Netmiko'},
 {'Technology': 'DS', 'Library': 'Pandas'},
 {'Technology': 'ML', 'Library': 'SciPy'},
 {'Technology': 'DL', 'Library': 'Keras'},
 {'Technology': 'RPA', 'Library': 'Tkinter'},
 {'Technology': 'Rest API', 'Library': 'Requests'}]

AI1
# Out:
# [{'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'Rest API', 'Library': 'Requests'}]

# %%
#A1.json dosyasini uret
#AI1 variable'ini json variable'i yap ve json dosyasina yazdir

with open('AI1.json','w') as f:
    f.write(json.dumps(AI1))

# %%
#json dosyasindan data frame uret
df1=pd.read_json('AI1.json')
df1
# Out:
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#AI1.json dosyasini python variable'ina cevir AI2 diye
with open('AI1.json') as f:
    AI2=json.load(f)
AI2
# Out:
# [{'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'Rest API', 'Library': 'Requests'}]

# %%
#python variable'i AI2'yi, AI3_json ismiyle json variable'ina cevir
AI3_json=json.dumps(AI2)
AI3_json
# Out:
# '[{"Technology": "NA", "Library": "Netmiko"}, {"Technology": "DS", "Library": "Pandas"}, {"Technology": "ML", "Library": "SciPy"}, {"Technology": "DL", "Library": "Keras"}, {"Technology": "RPA", "Library": "Tkinter"}, {"Technology": "Rest API", "Library": "Requests"}]'

# %%
#AI3_json isimli json variable'indan data frame uret df2 diye
df2=pd.read_json(AI3_json)
df2
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14776\587406017.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2=pd.read_json(AI3_json)
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
yeni={'NA':'Netmiko','DS':'Pandas','ML':'Scipy','DL':'Keras','RPA':'Tkinter','Rest API':'Requests'}
yeni
# Out:
# {'NA': 'Netmiko',
#  'DS': 'Pandas',
#  'ML': 'Scipy',
#  'DL': 'Keras',
#  'RPA': 'Tkinter',
#  'Rest API': 'Requests'}

# %%
#AI1 python variable'ini print et
AI1
# Out:
# [{'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'Rest API', 'Library': 'Requests'}]

# %%
#AI1 python variable'inin veri tipini print et
type(AI1)
# Out:
# list

# %%
#AI1 isimli python variable'indan data frame uret df3 diye
df3=pd.DataFrame(AI1)
df3
# Out:
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#yeni isimli python variable dictionary'den dataframe uret df4 diye
df4=pd.DataFrame.from_dict(yeni)
df4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 #yeni isimli python variable dictionary'den dataframe uret df4 diye
# ----> 2 df4=pd.DataFrame.from_dict(yeni)
#       3 df4
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1917, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1911     raise ValueError(
#    1912         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1913         f"Got '{orient}' instead"
#    1914     )
#    1916 if orient != "tight":
# -> 1917     return cls(data, index=index, columns=columns, dtype=dtype)
#    1918 else:
#    1919     realdata = data["data"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
# ...

# %%
#yeni isimli python variable dictionary'yi print et
yeni
#scalar : tek tip veri: int, str, float
#liste icinde farkli veri tipleri olursa; sorun yok. cunku scalar degil o zaman
# Out:
# {'NA': 'Netmiko',
#  'DS': 'Pandas',
#  'ML': 'Scipy',
#  'DL': 'Keras',
#  'RPA': 'Tkinter',
#  'Rest API': 'Requests'}

# %%
#index oryantasyonuyla 
#yeni isimli python variable dictionary'den dataframe uret df4 diye

df4=pd.DataFrame.from_dict(yeni,orient='index')
df4
# Out:
#                  0
# NA         Netmiko
# DS          Pandas
# ML           Scipy
# DL           Keras
# RPA        Tkinter
# Rest API  Requests

# %%
#index oryantasyonuyla 
#yeni isimli python variable dictionary'den dataframe uret df5 diye
#eksen 1 column adi Library olsun

df5=pd.DataFrame.from_dict(yeni,orient='index',columns=['Library'])
df5
# Out:
#            Library
# NA         Netmiko
# DS          Pandas
# ML           Scipy
# DL           Keras
# RPA        Tkinter
# Rest API  Requests

# %%
#T : transpose
df5.T
# Out:
#               NA      DS     ML     DL      RPA  Rest API
# Library  Netmiko  Pandas  Scipy  Keras  Tkinter  Requests

# %%
#df5'i transpose ederek, df6 uret
df6=df5.T
df6
# Out:
#               NA      DS     ML     DL      RPA  Rest API
# Library  Netmiko  Pandas  Scipy  Keras  Tkinter  Requests

# %%
#df1'i print et 
df1
# Out:
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#df1'i AI1.xlsx isim excel dosyasina donustur
df1.to_excel('AI1.xlsx')

# %%
# !pip install openpyxl

# %%
#AI1.xlsx'den dataframe uret: df1_excel
df1_excel=pd.read_excel('AI1.xlsx')
df1_excel
# Out:
#    Unnamed: 0 Technology   Library
# 0           0        NaN   Netmiko
# 1           1         DS    Pandas
# 2           2         ML     SciPy
# 3           3         DL     Keras
# 4           4        RPA   Tkinter
# 5           5   Rest API  Requests

# %%
#df1'i AI2.xlsx isim excel dosyasina donustur
#index olmadan
df1.to_excel('AI2.xlsx',index=False)

# %%
#AI2.xlsx'den dataframe uret: df2_excel
df2_excel=pd.read_excel('AI2.xlsx')
df2_excel
# Out:
#   Technology   Library
# 0        NaN   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#web sayfasini data frame'e cevir
#https://en.wikipedia.org/wiki/List_of_counties_in_Colorado
url='https://en.wikipedia.org/wiki/List_of_counties_in_Colorado'
df7=pd.read_html(url)
len(df7)
# Out:
# 11

# %%
#ssl exception ile
from urllib import request
import ssl
context = ssl._create_unverified_context()
response = request.urlopen(url, context=context)
html = response.read()
df7 = pd.read_html(html)

# %%
#2.index DataFrame'i gor
df7[2]
# Out:
#                     County       Territory or State Date created  \
# 0              Taos County  Territory of New Mexico   1852-01-09
# 1   Great Salt Lake County        Territory of Utah   1852-03-03
# 2       Green River County        Territory of Utah   1852-03-03
# 3              Iron County        Territory of Utah   1852-03-03
# 4           Sanpete County        Territory of Utah   1852-03-03
# 5              Utah County        Territory of Utah   1852-03-03
# 6        Washington County        Territory of Utah   1852-03-03
# 7          Arapahoe County      Territory of Kansas   1855-08-25
# 8            Beaver County        Territory of Utah   1856-01-05
# 9         Broderick County      Territory of Kansas   1859-02-07
# 10          El Paso County      Territory of Kansas   1859-02-07
# 11          Fremont County      Territory of Kansas   1859-02-07
# 12          Montana County      Territory of Kansas   1859-02-07
# ...

# %%
#The 13 highest mean elevation counties in the United States
#sadece bu tabloyu cek
#match
url='https://en.wikipedia.org/wiki/List_of_counties_in_Colorado'
df7_v2=pd.read_html(url,match='The 13 highest mean elevation counties in the United States')
df7_v2[0]
# Out:
#     Rank[g]              County      Mean elevation[f]    High point[14]  \
# 0         1         Lake County  11,702.5 feet 3,567 m      Mount Elbert
# 1         2     Hinsdale County    11,300 feet 3,444 m  Uncompahgre Peak
# 2         3      Mineral County    11,116 feet 3,388 m      Phoenix Peak
# 3         4     San Juan County    11,085 feet 3,379 m    Vermilion Peak
# 4         5       Summit County  10,935.5 feet 3,333 m        Grays Peak
# 5         6      Alamosa County  10,928.5 feet 3,331 m       Blanca Peak
# 6         7     Saguache County    10,915 feet 3,327 m     Crestone Peak
# 7         8     Costilla County  10,865.5 feet 3,312 m       Blanca Peak
# 8         9         Park County  10,705.5 feet 3,263 m     Mount Lincoln
# 9        10      Chaffee County    10,661 feet 3,249 m     Mount Harvard
# 10       11  Clear Creek County    10,608 feet 3,233 m        Grays Peak
# 11       12   Rio Grande County    10,402 feet 3,171 m      Bennett Peak
# ...

# %%
#Colorado nufus tahmin api
#https://data.colorado.gov/resource/q5vp-adf3.json
#Adams, 2000 yilindaki butun yaslari cek
import requests
url='https://data.colorado.gov/resource/q5vp-adf3.json'
response= requests.get(url)
response.json()
# Out:
# [{'id': '1',
#   'county': 'Colorado',
#   'fipscode': '0',
#   'year': '1990',
#   'age': '0',
#   'malepopulation': '26850',
#   'femalepopulation': '25695',
#   'totalpopulation': '52545',
#   'datatype': 'Estimate'},
#  {'id': '2',
#   'county': 'Colorado',
#   'fipscode': '0',
#   'year': '1990',
#   'age': '1',
#   'malepopulation': '25924',
#   'femalepopulation': '25081',
#   'totalpopulation': '51005',
#   'datatype': 'Estimate'},
#  {'id': '3',
#   'county': 'Colorado',
#   'fipscode': '0',
#   'year': '1990',
#   'age': '2',
#   'malepopulation': '25942',
#   'femalepopulation': '24659',
#   'totalpopulation': '50601',
#   'datatype': 'Estimate'},
#  {'id': '4',
#   'county': 'Colorado',
#   'fipscode': '0',
#   'year': '1990',
#   'age': '3',
#   'malepopulation': '26255',
#   'femalepopulation': '25106',
#   'totalpopulation': '51361',
#   'datatype': 'Estimate'},
#  {'id': '5',
#   'county': 'Colorado',
#   'fipscode': '0',
#   'year': '1990',
#   'age': '4',
# ...

# %%
#bu data ile df8 isimli dataframe olustur
df8=pd.DataFrame(response.json())
df8
# Out:
#        id    county fipscode  year age malepopulation femalepopulation  \
# 0       1  Colorado        0  1990   0          26850            25695
# 1       2  Colorado        0  1990   1          25924            25081
# 2       3  Colorado        0  1990   2          25942            24659
# 3       4  Colorado        0  1990   3          26255            25106
# 4       5  Colorado        0  1990   4          26654            25556
# ..    ...       ...      ...   ...  ..            ...              ...
# 995   996  Cheyenne       17  1990  85              0                4
# 996   997  Cheyenne       17  1990  86              3                7
# 997   998  Cheyenne       17  1990  87              1                3
# 998   999  Cheyenne       17  1990  88              1                4
# 999  1000  Cheyenne       17  1990  89              2                2
#
#     totalpopulation  datatype
# 0             52545  Estimate
# 1             51005  Estimate
# ...

# %% [raw]
# #dataframe'in info'sunu al
# df8.info()

# %%
#totalpopulation sutununu getir
df8['totalpopulation']
# Out:
# 0      52545
# 1      51005
# 2      50601
# 3      51361
# 4      52210
#        ...
# 995        4
# 996       10
# 997        4
# 998        5
# 999        4
# Name: totalpopulation, Length: 1000, dtype: object

# %%
#totalpopulation sutununun standart sapmasini al
df8['totalpopulation'].std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #totalpopulation sutununun standart sapmasini al
# ----> 2 df8['totalpopulation'].std()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6592, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6583 @doc(make_doc("std", ndim=1))
#    6584 def std(
#    6585     self,
#    (...)
#    6590     **kwargs,
#    6591 ):
# -> 6592     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12358, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12350 def std(
#   12351     self,
#   12352     axis: Axis | None = 0,
#    (...)
#   12356     **kwargs,
#   12357 ) -> Series | float:
# > 12358     return self._stat_function_ddof(
# ...

# %%
#numpy kutuphanesini yukle
# !pip install numpy

# %%
#numpy kutuphanesini import et
#0-1 arasinda random sayi uret
import numpy as np

# %%
np.random.random()
# Out:
# 0.5819288784244522

# %%
#1-100 arasinda random sayi uret
np.random.randint(1,100)
# Out:
# 11

# %%
#2 array icinde 4 index'li random float sayilar uret
#data variable
data=np.random.randn(2,6)
data
# Out:
# array([[ 1.05343092e+00,  2.17493750e+00,  5.06528867e-01,
#         -1.64577711e+00, -1.05854410e-04,  1.23269972e+00],
#        [ 2.24405387e+00, -3.10237822e-01,  2.00782937e-01,
#         -4.50860921e-01, -4.01134225e-01, -7.80086800e-01]])

# %%
#data variable'inin veri tipi ne
data.dtype
# Out:
# dtype('float64')

# %%
#4 array icinde 2 index'li 1-100 arasinda random int sayilar uret
#data1 variable
data1=np.random.randint(1,100,size=(4,2))
data1
# Out:
# array([[98, 56],
#        [ 4, 35],
#        [29, 34],
#        [56, 93]])

# %%
#data1 variable'inin veri tipi ne
data1.dtype
# Out:
# dtype('int32')

# %%
#data variable'inin veri tipini int64 bit yap
#data_int variable'ina ata
data_int=data.astype('int64')
data_int
# Out:
# array([[ 1,  2,  0, -1,  0,  1],
#        [ 2,  0,  0,  0,  0,  0]], dtype=int64)

# %%
#data_int variable'inin veri tipi ne
data_int.dtype
# Out:
# dtype('int64')

# %%
#data1 variable'inin veri tipini float32 bit yap
#data1_float variable'ina ata
data1_float=data1.astype('float32')
data1_float
# Out:
# array([[98., 56.],
#        [ 4., 35.],
#        [29., 34.],
#        [56., 93.]], dtype=float32)

# %%
#data1_float variable'inin veri tipi ne
data1_float.dtype
# Out:
# dtype('float32')

# %%
#df8 dataframe'inde totalpopulation sutunun veri tipini float32 yap
#astype
df8['totalpopulation']=df8['totalpopulation'].astype('float32')
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   county            1000 non-null   object
#  2   fipscode          1000 non-null   object
#  3   year              1000 non-null   object
#  4   age               1000 non-null   object
#  5   malepopulation    1000 non-null   object
#  6   femalepopulation  1000 non-null   object
#  7   totalpopulation   1000 non-null   float32
#  8   datatype          1000 non-null   object
# dtypes: float32(1), object(8)
# memory usage: 66.5+ KB

# %%
#df8 dataframe'inde totalpopulation column'unu getir
df8['totalpopulation']
# Out:
# 0      52545.0
# 1      51005.0
# 2      50601.0
# 3      51361.0
# 4      52210.0
#         ...
# 995        4.0
# 996       10.0
# 997        4.0
# 998        5.0
# 999        4.0
# Name: totalpopulation, Length: 1000, dtype: float32

# %%
#df8 dataframe'inde totalpopulation column'unun toplamini al
df8['totalpopulation'].sum()
# Out:
# 4232523.0

# %%
#df8 dataframe'inde totalpopulation column'unundaki en yuksek sayiyi al
df8['totalpopulation'].max()
# Out:
# 65059.0

# %%
#df8 dataframe'inde totalpopulation column'unundaki en dusuk sayiyi al
df8['totalpopulation'].min()
# Out:
# 0.0

# %%
#df8 dataframe'inde totalpopulation column'unun standart sapmasini al
df8['totalpopulation'].std()
# Out:
# 11759.7607421875

# %%
#df8 dataframe'inde totalpopulation column'unun degerlerini al
df8['totalpopulation'].values
# Out:
# array([5.2545e+04, 5.1005e+04, 5.0601e+04, 5.1361e+04, 5.2210e+04,
#        5.0931e+04, 5.1036e+04, 5.1534e+04, 4.8489e+04, 5.1109e+04,
#        4.9469e+04, 4.5988e+04, 4.4964e+04, 4.3917e+04, 4.2979e+04,
#        4.2856e+04, 4.1799e+04, 4.3890e+04, 4.6102e+04, 5.2435e+04,
#        5.1163e+04, 4.8856e+04, 4.6111e+04, 4.6032e+04, 4.8546e+04,
#        5.2609e+04, 5.5580e+04, 5.8766e+04, 5.8514e+04, 6.5059e+04,
#        6.4778e+04, 6.3768e+04, 6.4886e+04, 6.4424e+04, 6.4943e+04,
#        6.4093e+04, 6.2410e+04, 6.1992e+04, 5.7437e+04, 5.9352e+04,
#        5.7157e+04, 5.5037e+04, 5.5464e+04, 5.4107e+04, 4.0964e+04,
#        4.1201e+04, 4.0103e+04, 3.9985e+04, 3.3783e+04, 3.3845e+04,
#        3.1820e+04, 3.0387e+04, 2.9010e+04, 2.7658e+04, 2.7865e+04,
#        2.7172e+04, 2.5412e+04, 2.5710e+04, 2.5035e+04, 2.6503e+04,
#        2.5617e+04, 2.4739e+04, 2.4559e+04, 2.3517e+04, 2.3411e+04,
#        2.3709e+04, 2.2921e+04, 2.2040e+04, 2.1893e+04, 2.0555e+04,
# ...

# %%
#df8 dataframe'inin column'larini al
df8.columns
# Out:
# Index(['id', 'county', 'fipscode', 'year', 'age', 'malepopulation',
#        'femalepopulation', 'totalpopulation', 'datatype'],
#       dtype='object')

# %%
#nufusu en yuksek olan verinin tamami
df8[df8['totalpopulation']==df8['totalpopulation'].max()]
# Out:
#     id    county fipscode  year age malepopulation femalepopulation  \
# 29  30  Colorado        0  1990  29          32389            32670
#
#     totalpopulation  datatype
# 29          65059.0  Estimate

# %%
#nufusu en yuksek olan verinin yasi
df8[df8['totalpopulation']==df8['totalpopulation'].max()]['age']
# Out:
# 29    29
# Name: age, dtype: object

# %%
#nufusu en yuksek olan verinin yasi
#values
df8[df8['totalpopulation']==df8['totalpopulation'].max()]['age'].values
# Out:
# array(['29'], dtype=object)

# %%
#direk yasi getir sadece
df8[df8['totalpopulation']==df8['totalpopulation'].max()]['age'].values[0]
# Out:
# '29'

# %%
#df8 dataframe'inin info al
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   county            1000 non-null   object
#  2   fipscode          1000 non-null   object
#  3   year              1000 non-null   object
#  4   age               1000 non-null   object
#  5   malepopulation    1000 non-null   object
#  6   femalepopulation  1000 non-null   object
#  7   totalpopulation   1000 non-null   float32
#  8   datatype          1000 non-null   object
# dtypes: float32(1), object(8)
# memory usage: 66.5+ KB

# %%
#df8 sadece datatipi object olanlari al X diye
df8_object=df8.select_dtypes(include='object')
df8_object
# Out:
#        id    county fipscode  year age malepopulation femalepopulation  \
# 0       1  Colorado        0  1990   0          26850            25695
# 1       2  Colorado        0  1990   1          25924            25081
# 2       3  Colorado        0  1990   2          25942            24659
# 3       4  Colorado        0  1990   3          26255            25106
# 4       5  Colorado        0  1990   4          26654            25556
# ..    ...       ...      ...   ...  ..            ...              ...
# 995   996  Cheyenne       17  1990  85              0                4
# 996   997  Cheyenne       17  1990  86              3                7
# 997   998  Cheyenne       17  1990  87              1                3
# 998   999  Cheyenne       17  1990  88              1                4
# 999  1000  Cheyenne       17  1990  89              2                2
#
#      datatype
# 0    Estimate
# 1    Estimate
# 2    Estimate
# 3    Estimate
# 4    Estimate
# ..        ...
# ...

# %%
#df8 sadece datatipi object olanlarin columlarini al
df8_object_columns=df8.select_dtypes(include='object').columns
df8_object_columns
# Out:
# Index(['id', 'county', 'fipscode', 'year', 'age', 'malepopulation',
#        'femalepopulation', 'datatype'],
#       dtype='object')

# %%
#df8 sadece datatipi object olanlarin value'larini al
df8_object_values=df8.select_dtypes(include='object').values
df8_object_values
# Out:
# array([['1', 'Colorado', '0', ..., '26850', '25695', 'Estimate'],
#        ['2', 'Colorado', '0', ..., '25924', '25081', 'Estimate'],
#        ['3', 'Colorado', '0', ..., '25942', '24659', 'Estimate'],
#        ...,
#        ['998', 'Cheyenne', '17', ..., '1', '3', 'Estimate'],
#        ['999', 'Cheyenne', '17', ..., '1', '4', 'Estimate'],
#        ['1000', 'Cheyenne', '17', ..., '2', '2', 'Estimate']],
#       dtype=object)

# %%
df8[df8_object_columns]
# Out:
#        id    county fipscode  year age malepopulation femalepopulation  \
# 0       1  Colorado        0  1990   0          26850            25695
# 1       2  Colorado        0  1990   1          25924            25081
# 2       3  Colorado        0  1990   2          25942            24659
# 3       4  Colorado        0  1990   3          26255            25106
# 4       5  Colorado        0  1990   4          26654            25556
# ..    ...       ...      ...   ...  ..            ...              ...
# 995   996  Cheyenne       17  1990  85              0                4
# 996   997  Cheyenne       17  1990  86              3                7
# 997   998  Cheyenne       17  1990  87              1                3
# 998   999  Cheyenne       17  1990  88              1                4
# 999  1000  Cheyenne       17  1990  89              2                2
#
#      datatype
# 0    Estimate
# 1    Estimate
# 2    Estimate
# 3    Estimate
# 4    Estimate
# ..        ...
# ...

# %%
#df8 sadece datatipi float32 olanlari al df8_float32 diye
df8_float32=df8.select_dtypes(include=np.float32)
df8_float32
# Out:
#      totalpopulation
# 0            52545.0
# 1            51005.0
# 2            50601.0
# 3            51361.0
# 4            52210.0
# ..               ...
# 995              4.0
# 996             10.0
# 997              4.0
# 998              5.0
# 999              4.0
#
# [1000 rows x 1 columns]

# %%
#df8 dataframe'inin column'larini al
df8.columns
# Out:
# Index(['id', 'county', 'fipscode', 'year', 'age', 'malepopulation',
#        'femalepopulation', 'totalpopulation', 'datatype'],
#       dtype='object')

# %%
#totalpopulation column'unu malepopulation'dan once gelsin df8'de
columnlar=list(df8.columns)
columnlar
# Out:
# ['id',
#  'county',
#  'fipscode',
#  'year',
#  'age',
#  'malepopulation',
#  'femalepopulation',
#  'totalpopulation',
#  'datatype']

# %%
columnlar.index('totalpopulation')
# Out:
# 7

# %%
columnlar[7]
# Out:
# 'totalpopulation'

# %%
df8_float32_column=df8.select_dtypes(include=np.float32).columns.values[0]
df8_float32_column
# Out:
# 'totalpopulation'

# %%
df8['malepopulation']=df8['malepopulation'].astype('int32')
df8
# Out:
#        id    county fipscode  year age  malepopulation femalepopulation  \
# 0       1  Colorado        0  1990   0           26850            25695
# 1       2  Colorado        0  1990   1           25924            25081
# 2       3  Colorado        0  1990   2           25942            24659
# 3       4  Colorado        0  1990   3           26255            25106
# 4       5  Colorado        0  1990   4           26654            25556
# ..    ...       ...      ...   ...  ..             ...              ...
# 995   996  Cheyenne       17  1990  85               0                4
# 996   997  Cheyenne       17  1990  86               3                7
# 997   998  Cheyenne       17  1990  87               1                3
# 998   999  Cheyenne       17  1990  88               1                4
# 999  1000  Cheyenne       17  1990  89               2                2
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# 1            51005.0  Estimate
# ...

# %%
df8_int32_column=df8.select_dtypes(include=np.int32).columns.values[0]
df8_int32_column
# Out:
# 'malepopulation'

# %%
columnlar.index(df8_float32_column)
# Out:
# 7

# %%
columnlar.index(df8_int32_column)
# Out:
# 5

# %%
columnlar[columnlar.index(df8_float32_column)]=df8_int32_column
columnlar[columnlar.index(df8_int32_column)]=df8_float32_column
columnlar
# Out:
# ['id',
#  'county',
#  'fipscode',
#  'year',
#  'age',
#  'totalpopulation',
#  'femalepopulation',
#  'malepopulation',
#  'datatype']

# %%
df8_v2=df8[columnlar]
df8_v2
# Out:
#        id    county fipscode  year age  totalpopulation femalepopulation  \
# 0       1  Colorado        0  1990   0          52545.0            25695
# 1       2  Colorado        0  1990   1          51005.0            25081
# 2       3  Colorado        0  1990   2          50601.0            24659
# 3       4  Colorado        0  1990   3          51361.0            25106
# 4       5  Colorado        0  1990   4          52210.0            25556
# ..    ...       ...      ...   ...  ..              ...              ...
# 995   996  Cheyenne       17  1990  85              4.0                4
# 996   997  Cheyenne       17  1990  86             10.0                7
# 997   998  Cheyenne       17  1990  87              4.0                3
# 998   999  Cheyenne       17  1990  88              5.0                4
# 999  1000  Cheyenne       17  1990  89              4.0                2
#
#      malepopulation  datatype
# 0             26850  Estimate
# ...

# %%
#df8 dataframe'inde femalepopulation sutunun veri tipini int32 yap
#df8 dataframe'inde year sutunun veri tipini int32 yap
#df8 dataframe'inde age sutunun veri tipini int32 yap
#df8 dataframe'inin info al
#astype
df8['femalepopulation']=df8['femalepopulation'].astype('int32')
df8['year']=df8['year'].astype('int32')
df8['age']=df8['age'].astype('int32')
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   county            1000 non-null   object
#  2   fipscode          1000 non-null   object
#  3   year              1000 non-null   int32
#  4   age               1000 non-null   int32
#  5   malepopulation    1000 non-null   int32
#  6   femalepopulation  1000 non-null   int32
#  7   totalpopulation   1000 non-null   float32
#  8   datatype          1000 non-null   object
# dtypes: float32(1), int32(4), object(4)
# memory usage: 50.9+ KB

# %%
#df8 sadece datatipi object olanlari al X2 diye
X2=df8.select_dtypes(include='object')
X2
# Out:
#        id    county fipscode  datatype
# 0       1  Colorado        0  Estimate
# 1       2  Colorado        0  Estimate
# 2       3  Colorado        0  Estimate
# 3       4  Colorado        0  Estimate
# 4       5  Colorado        0  Estimate
# ..    ...       ...      ...       ...
# 995   996  Cheyenne       17  Estimate
# 996   997  Cheyenne       17  Estimate
# 997   998  Cheyenne       17  Estimate
# 998   999  Cheyenne       17  Estimate
# 999  1000  Cheyenne       17  Estimate
#
# [1000 rows x 4 columns]

# %%
#sadece datatipi int32  float32 olanlari al X3 diye
X3=df8.select_dtypes(include=(np.float32,np.int32))
X3
# Out:
#      year  age  malepopulation  femalepopulation  totalpopulation
# 0    1990    0           26850             25695          52545.0
# 1    1990    1           25924             25081          51005.0
# 2    1990    2           25942             24659          50601.0
# 3    1990    3           26255             25106          51361.0
# 4    1990    4           26654             25556          52210.0
# ..    ...  ...             ...               ...              ...
# 995  1990   85               0                 4              4.0
# 996  1990   86               3                 7             10.0
# 997  1990   87               1                 3              4.0
# 998  1990   88               1                 4              5.0
# 999  1990   89               2                 2              4.0
#
# [1000 rows x 5 columns]

# %%
#df8 sadece datatipi object olanlarin columlarini al
X2_columns=df8.select_dtypes(include='object').columns
X2_columns
# Out:
# Index(['id', 'county', 'fipscode', 'datatype'], dtype='object')

# %%
#df8 sadece datatipi object olanlarin value'larini al
X2_values=df8.select_dtypes(include='object').values
X2_values
# Out:
# array([['1', 'Colorado', '0', 'Estimate'],
#        ['2', 'Colorado', '0', 'Estimate'],
#        ['3', 'Colorado', '0', 'Estimate'],
#        ...,
#        ['998', 'Cheyenne', '17', 'Estimate'],
#        ['999', 'Cheyenne', '17', 'Estimate'],
#        ['1000', 'Cheyenne', '17', 'Estimate']], dtype=object)

# %%
#df8 print et
df8
# Out:
#        id    county fipscode  year  age  malepopulation  femalepopulation  \
# 0       1  Colorado        0  1990    0           26850             25695
# 1       2  Colorado        0  1990    1           25924             25081
# 2       3  Colorado        0  1990    2           25942             24659
# 3       4  Colorado        0  1990    3           26255             25106
# 4       5  Colorado        0  1990    4           26654             25556
# ..    ...       ...      ...   ...  ...             ...               ...
# 995   996  Cheyenne       17  1990   85               0                 4
# 996   997  Cheyenne       17  1990   86               3                 7
# 997   998  Cheyenne       17  1990   87               1                 3
# 998   999  Cheyenne       17  1990   88               1                 4
# 999  1000  Cheyenne       17  1990   89               2                 2
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#df8 info al
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   county            1000 non-null   object
#  2   fipscode          1000 non-null   object
#  3   year              1000 non-null   int32
#  4   age               1000 non-null   int32
#  5   malepopulation    1000 non-null   int32
#  6   femalepopulation  1000 non-null   int32
#  7   totalpopulation   1000 non-null   float32
#  8   datatype          1000 non-null   object
# dtypes: float32(1), int32(4), object(4)
# memory usage: 50.9+ KB

# %%
#df8 totalpopulation 500'den buyuk olanlari al=>df9
df8[df8['totalpopulation']>500]
# Out:
#       id    county fipscode  year  age  malepopulation  femalepopulation  \
# 0      1  Colorado        0  1990    0           26850             25695
# 1      2  Colorado        0  1990    1           25924             25081
# 2      3  Colorado        0  1990    2           25942             24659
# 3      4  Colorado        0  1990    3           26255             25106
# 4      5  Colorado        0  1990    4           26654             25556
# ..   ...       ...      ...   ...  ...             ...               ...
# 714  715   Boulder       13  1990   77             247               422
# 715  716   Boulder       13  1990   78             239               401
# 716  717   Boulder       13  1990   79             225               385
# 717  718   Boulder       13  1990   80             178               353
# 727  728   Boulder       13  1990   90             140               531
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#df8 totalpopulation 500'den buyuk olanlari ve age de 50'den kucuk olanlari al=>df10
df8[(df8['totalpopulation']>500)&(df8['age']<50)]
# Out:
#       id    county fipscode  year  age  malepopulation  femalepopulation  \
# 0      1  Colorado        0  1990    0           26850             25695
# 1      2  Colorado        0  1990    1           25924             25081
# 2      3  Colorado        0  1990    2           25942             24659
# 3      4  Colorado        0  1990    3           26255             25106
# 4      5  Colorado        0  1990    4           26654             25556
# ..   ...       ...      ...   ...  ...             ...               ...
# 682  683   Boulder       13  1990   45            1490              1478
# 683  684   Boulder       13  1990   46            1439              1399
# 684  685   Boulder       13  1990   47            1426              1472
# 685  686   Boulder       13  1990   48            1081              1230
# 686  687   Boulder       13  1990   49            1131              1149
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#df8 de yasi sort et kucukten buyuge
#df8_yas_asc
df8_yas_asc=df8.sort_values('age')
df8_yas_asc
# Out:
#       id      county fipscode  year  age  malepopulation  femalepopulation  \
# 0      1    Colorado        0  1990    0           26850             25695
# 182  183     Alamosa        3  1990    0             116               102
# 273  274    Arapahoe        5  1990    0            3166              3069
# 910  911    Cheyenne       17  1990    0              25                18
# 637  638     Boulder       13  1990    0            1597              1630
# ..   ...         ...      ...   ...  ...             ...               ...
# 636  637        Bent       11  1990   90               6                21
# 818  819  Broomfield       14  1990   90               0                 0
# 90    91    Colorado        0  1990   90            2559              8600
# 363  364    Arapahoe        5  1990   90             151               640
# 545  546        Baca        9  1990   90               9                25
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#df8 de yasi sort et buyukten kucuge
#df8_yas_desc
df8_yas_desc=df8.sort_values('age',ascending=False)
df8_yas_desc
# Out:
#       id      county fipscode  year  age  malepopulation  femalepopulation  \
# 90    91    Colorado        0  1990   90            2559              8600
# 636  637        Bent       11  1990   90               6                21
# 272  273     Alamosa        3  1990   90              11                44
# 181  182       Adams        1  1990   90             144               437
# 818  819  Broomfield       14  1990   90               0                 0
# ..   ...         ...      ...   ...  ...             ...               ...
# 728  729  Broomfield       14  1990    0               0                 0
# 182  183     Alamosa        3  1990    0             116               102
# 819  820     Chaffee       15  1990    0              70                66
# 91    92       Adams        1  1990    0            2354              2404
# 0      1    Colorado        0  1990    0           26850             25695
#
#      totalpopulation  datatype
# 90           11159.0  Estimate
# ...

# %%
#id column'unu index yap
df8=df8.set_index('id')
df8
# Out:
#         county fipscode  year  age  malepopulation  femalepopulation  \
# id
# 1     Colorado        0  1990    0           26850             25695
# 2     Colorado        0  1990    1           25924             25081
# 3     Colorado        0  1990    2           25942             24659
# 4     Colorado        0  1990    3           26255             25106
# 5     Colorado        0  1990    4           26654             25556
# ...        ...      ...   ...  ...             ...               ...
# 996   Cheyenne       17  1990   85               0                 4
# 997   Cheyenne       17  1990   86               3                 7
# 998   Cheyenne       17  1990   87               1                 3
# 999   Cheyenne       17  1990   88               1                 4
# 1000  Cheyenne       17  1990   89               2                 2
#
#       totalpopulation  datatype
# id
# 1             52545.0  Estimate
# 2             51005.0  Estimate
# ...

# %%
#geri al
df8=df8.reset_index()
df8
# Out:
#        id    county fipscode  year  age  malepopulation  femalepopulation  \
# 0       1  Colorado        0  1990    0           26850             25695
# 1       2  Colorado        0  1990    1           25924             25081
# 2       3  Colorado        0  1990    2           25942             24659
# 3       4  Colorado        0  1990    3           26255             25106
# 4       5  Colorado        0  1990    4           26654             25556
# ..    ...       ...      ...   ...  ...             ...               ...
# 995   996  Cheyenne       17  1990   85               0                 4
# 996   997  Cheyenne       17  1990   86               3                 7
# 997   998  Cheyenne       17  1990   87               1                 3
# 998   999  Cheyenne       17  1990   88               1                 4
# 999  1000  Cheyenne       17  1990   89               2                 2
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#id column'unu index yap
df8=df8.set_index('id')
df8
# Out:
#         county fipscode  year  age  malepopulation  femalepopulation  \
# id
# 1     Colorado        0  1990    0           26850             25695
# 2     Colorado        0  1990    1           25924             25081
# 3     Colorado        0  1990    2           25942             24659
# 4     Colorado        0  1990    3           26255             25106
# 5     Colorado        0  1990    4           26654             25556
# ...        ...      ...   ...  ...             ...               ...
# 996   Cheyenne       17  1990   85               0                 4
# 997   Cheyenne       17  1990   86               3                 7
# 998   Cheyenne       17  1990   87               1                 3
# 999   Cheyenne       17  1990   88               1                 4
# 1000  Cheyenne       17  1990   89               2                 2
#
#       totalpopulation  datatype
# id
# 1             52545.0  Estimate
# 2             51005.0  Estimate
# ...

# %%
#index ismini degistir: number
df8.index.name='number'
df8
# Out:
#           county fipscode  year  age  malepopulation  femalepopulation  \
# number
# 1       Colorado        0  1990    0           26850             25695
# 2       Colorado        0  1990    1           25924             25081
# 3       Colorado        0  1990    2           25942             24659
# 4       Colorado        0  1990    3           26255             25106
# 5       Colorado        0  1990    4           26654             25556
# ...          ...      ...   ...  ...             ...               ...
# 996     Cheyenne       17  1990   85               0                 4
# 997     Cheyenne       17  1990   86               3                 7
# 998     Cheyenne       17  1990   87               1                 3
# 999     Cheyenne       17  1990   88               1                 4
# 1000    Cheyenne       17  1990   89               2                 2
#
#         totalpopulation  datatype
# number
# 1               52545.0  Estimate
# ...

# %%
#index ismini degistir: None
df8.index.name=None
df8
# Out:
#         county fipscode  year  age  malepopulation  femalepopulation  \
# 1     Colorado        0  1990    0           26850             25695
# 2     Colorado        0  1990    1           25924             25081
# 3     Colorado        0  1990    2           25942             24659
# 4     Colorado        0  1990    3           26255             25106
# 5     Colorado        0  1990    4           26654             25556
# ...        ...      ...   ...  ...             ...               ...
# 996   Cheyenne       17  1990   85               0                 4
# 997   Cheyenne       17  1990   86               3                 7
# 998   Cheyenne       17  1990   87               1                 3
# 999   Cheyenne       17  1990   88               1                 4
# 1000  Cheyenne       17  1990   89               2                 2
#
#       totalpopulation  datatype
# 1             52545.0  Estimate
# 2             51005.0  Estimate
# 3             50601.0  Estimate
# ...

# %%
#geri al 
df8=df8.reset_index()
df8
# Out:
#     index    county fipscode  year  age  malepopulation  femalepopulation  \
# 0       1  Colorado        0  1990    0           26850             25695
# 1       2  Colorado        0  1990    1           25924             25081
# 2       3  Colorado        0  1990    2           25942             24659
# 3       4  Colorado        0  1990    3           26255             25106
# 4       5  Colorado        0  1990    4           26654             25556
# ..    ...       ...      ...   ...  ...             ...               ...
# 995   996  Cheyenne       17  1990   85               0                 4
# 996   997  Cheyenne       17  1990   86               3                 7
# 997   998  Cheyenne       17  1990   87               1                 3
# 998   999  Cheyenne       17  1990   88               1                 4
# 999  1000  Cheyenne       17  1990   89               2                 2
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#column adi index'i id yap
df8=df8.rename(index={'index':'id'})
df8
# Out:
#     index    county fipscode  year  age  malepopulation  femalepopulation  \
# 0       1  Colorado        0  1990    0           26850             25695
# 1       2  Colorado        0  1990    1           25924             25081
# 2       3  Colorado        0  1990    2           25942             24659
# 3       4  Colorado        0  1990    3           26255             25106
# 4       5  Colorado        0  1990    4           26654             25556
# ..    ...       ...      ...   ...  ...             ...               ...
# 995   996  Cheyenne       17  1990   85               0                 4
# 996   997  Cheyenne       17  1990   86               3                 7
# 997   998  Cheyenne       17  1990   87               1                 3
# 998   999  Cheyenne       17  1990   88               1                 4
# 999  1000  Cheyenne       17  1990   89               2                 2
#
#      totalpopulation  datatype
# 0            52545.0  Estimate
# ...

# %%
#df1 print et
df1
# Out:
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#df1 dataframe'i liste icinde dict cevir
#df1_array
df1_array=df1.to_dict(orient='records')
df1_array
# Out:
# [{'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'Rest API', 'Library': 'Requests'}]

# %%
#df1 dataframe'i dict cevir
#df1_dict
df1_dict=df1.to_dict()
df1_dict
# Out:
# {'Technology': {0: 'NA', 1: 'DS', 2: 'ML', 3: 'DL', 4: 'RPA', 5: 'Rest API'},
#  'Library': {0: 'Netmiko',
#   1: 'Pandas',
#   2: 'SciPy',
#   3: 'Keras',
#   4: 'Tkinter',
#   5: 'Requests'}}

# %%
#df1 print et
df1
# Out:
#   Technology   Library
# 0         NA   Netmiko
# 1         DS    Pandas
# 2         ML     SciPy
# 3         DL     Keras
# 4        RPA   Tkinter
# 5   Rest API  Requests

# %%
#df1 dataframe'de Technology value'su Rest API olan index'in Library value'su nedir
df1[df1['Technology']=='Rest API']['Library'].values[0]
# Out:
# 'Requests'

# %%
veri=[{'Technology':'Api','Library':'Flask-restx'},
     {'Technology':'api','Library':'Gradio'}]
veri
# Out:
# [{'Technology': 'Api', 'Library': 'Flask-restx'},
#  {'Technology': 'api', 'Library': 'Gradio'}]

# %%
#veri variable'indan df_veri olustur
df_veri=pd.DataFrame(veri)
df_veri
# Out:
#   Technology      Library
# 0        Api  Flask-restx
# 1        api       Gradio

# %%
#df1'e df_veri'yi ekle asagiya dogru index ile (index kaldigi yerden devam edecek sekilde)
df1=pd.concat([df1,df_veri],ignore_index=True)
df1
# Out:
#   Technology      Library
# 0         NA      Netmiko
# 1         DS       Pandas
# 2         ML        SciPy
# 3         DL        Keras
# 4        RPA      Tkinter
# 5   Rest API     Requests
# 6        Api  Flask-restx
# 7        api       Gradio

# %%
#df1 dataframe'de Technology value'sunun icinde API, Api, api olan verilerin Library value'larini getir
df1.loc[df1['Technology'].str.contains('API|Api|api')] ['Library'].values
# Out:
# array(['Requests', 'Flask-restx', 'Gradio'], dtype=object)

# %%
veri2={'Language':['Python','Python','Python','Python','Python','Python','Python','Python'],
        'version':[3,3,3,3,3,3,3,3]}
veri2
# Out:
# {'Language': ['Python',
#   'Python',
#   'Python',
#   'Python',
#   'Python',
#   'Python',
#   'Python',
#   'Python'],
#  'version': [3, 3, 3, 3, 3, 3, 3, 3]}

# %%
#veri2 variable'indan df_veri2 olustur
df_veri2=pd.DataFrame.from_dict(veri2)
df_veri2
# Out:
#   Language  version
# 0   Python        3
# 1   Python        3
# 2   Python        3
# 3   Python        3
# 4   Python        3
# 5   Python        3
# 6   Python        3
# 7   Python        3

# %%
#df1'e df_veri2'yi ekle saga dogru yeni columnlar olarak
df1=pd.concat([df1,df_veri2],axis=1)
df1
# Out:
#   Technology      Library Language  version
# 0         NA      Netmiko   Python        3
# 1         DS       Pandas   Python        3
# 2         ML        SciPy   Python        3
# 3         DL        Keras   Python        3
# 4        RPA      Tkinter   Python        3
# 5   Rest API     Requests   Python        3
# 6        Api  Flask-restx   Python        3
# 7        api       Gradio   Python        3

# %%
#df1'e hoca olarak Erdeniz Unvan verisini ekle
df1['Hoca']='Erdeniz Unvan'
df1
# Out:
#   Technology      Library Language  version           Hoca
# 0         NA      Netmiko   Python        3  Erdeniz Unvan
# 1         DS       Pandas   Python        3  Erdeniz Unvan
# 2         ML        SciPy   Python        3  Erdeniz Unvan
# 3         DL        Keras   Python        3  Erdeniz Unvan
# 4        RPA      Tkinter   Python        3  Erdeniz Unvan
# 5   Rest API     Requests   Python        3  Erdeniz Unvan
# 6        Api  Flask-restx   Python        3  Erdeniz Unvan
# 7        api       Gradio   Python        3  Erdeniz Unvan

# %%
#df1 'de Language version Hoca columnlarini sil
df1=df1.drop(columns=['Language','version','Hoca'])
df1
# Out:
#   Technology      Library
# 0         NA      Netmiko
# 1         DS       Pandas
# 2         ML        SciPy
# 3         DL        Keras
# 4        RPA      Tkinter
# 5   Rest API     Requests
# 6        Api  Flask-restx
# 7        api       Gradio

# %%
#df1 'de 5 ve 7.ci indexleri sil
df1=df1.drop(index=[5,7])
df1
# Out:
#   Technology      Library
# 0         NA      Netmiko
# 1         DS       Pandas
# 2         ML        SciPy
# 3         DL        Keras
# 4        RPA      Tkinter
# 6        Api  Flask-restx

# %%
#df1 'de Technology column'unu Teknoloji ve Library column'unu Kütüphane yap
#df1 'de 0,1,2,3,4,6 index 'lerini A, B, C, D,E, G yap
df1=df1.rename(index={0:'A',1:'B',2:'C',3:'D',4:'E',6:'G'},columns={'Technology':'Teknoloji','Library':'Kütüphane'})
df1
# Out:
#   Teknoloji    Kütüphane
# A        NA      Netmiko
# B        DS       Pandas
# C        ML        SciPy
# D        DL        Keras
# E       RPA      Tkinter
# G       Api  Flask-restx

# %%
#df1 'de Teknoloji column'unda NA'yi ağ otomasyonu, ve DS'yi veri bilimi yap
df1['Teknoloji']=df1['Teknoloji'].replace('NA','Ağ otomasyonu')
df1['Teknoloji']=df1['Teknoloji'].replace('DS','veri bilimi')
df1
# Out:
#        Teknoloji    Kütüphane
# A  Ağ otomasyonu      Netmiko
# B    veri bilimi       Pandas
# C             ML        SciPy
# D             DL        Keras
# E            RPA      Tkinter
# G            Api  Flask-restx

# %%
#df1 'de A, B, C, D,E, G index 'lerini  0,1,2,3,4,6 yap
df1=df1.rename(index={'A':0,'B':1,'C':2,'D':3,'E':4,'G':6})
df1
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1    veri bilimi       Pandas
# 2             ML        SciPy
# 3             DL        Keras
# 4            RPA      Tkinter
# 6            Api  Flask-restx

# %%
#df1'de 1 index'ini getir
df1.iloc[1]
# Out:
# Teknoloji    veri bilimi
# Kütüphane         Pandas
# Name: 1, dtype: object

# %%
#df1'de 1'den 4'e kadar olan index'leri getir
df1.iloc[1:4]
# Out:
#      Teknoloji Kütüphane
# 1  veri bilimi    Pandas
# 2           ML     SciPy
# 3           DL     Keras

# %%
#df1'de sadece 1 ve 4 index'lerini getir
df1.iloc[[1,4]]
# Out:
#      Teknoloji Kütüphane
# 1  veri bilimi    Pandas
# 4          RPA   Tkinter

# %%
#df1 print et
df1
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1    veri bilimi       Pandas
# 2             ML        SciPy
# 3             DL        Keras
# 4            RPA      Tkinter
# 6            Api  Flask-restx

# %%
#df1'de sadece 1 ve 4 index'lerin verilerinin yerlerini degistir
df1.iloc[[1,4]]=df1.iloc[[4,1]].values
df1
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1            RPA      Tkinter
# 2             ML        SciPy
# 3             DL        Keras
# 4    veri bilimi       Pandas
# 6            Api  Flask-restx

# %%
#df1 'de Kütüphane column'unda Tkinter'i NaN yap
df1['Kütüphane']=df1['Kütüphane'].replace('Tkinter',np.NaN)
df1
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1            RPA          NaN
# 2             ML        SciPy
# 3             DL        Keras
# 4    veri bilimi       Pandas
# 6            Api  Flask-restx

# %%
#df1 info al
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Teknoloji  6 non-null      object
#  1   Kütüphane  5 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %%
#df1'de hangi column'da ne kadar eksik veri var gor
df1.isna().sum()
# Out:
# Teknoloji    0
# Kütüphane    1
# dtype: int64

# %%
#df1'de eksik veriye sahip index'i gor
df1[df1['Kütüphane'].isna()]
# Out:
#   Teknoloji Kütüphane
# 1       RPA       NaN

# %%
#df1'i kopyala df1_x
df1_x=df1.copy()
df1_x
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1            RPA          NaN
# 2             ML        SciPy
# 3             DL        Keras
# 4    veri bilimi       Pandas
# 6            Api  Flask-restx

# %%
#df1_x'de eksik verileri sil
df1_x=df1_x.dropna()
df1_x
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 2             ML        SciPy
# 3             DL        Keras
# 4    veri bilimi       Pandas
# 6            Api  Flask-restx

# %%
#df1'de eksik verileri Library ile doldur
df1=df1.fillna('Library')
df1
# Out:
#        Teknoloji    Kütüphane
# 0  Ağ otomasyonu      Netmiko
# 1            RPA      Library
# 2             ML        SciPy
# 3             DL        Keras
# 4    veri bilimi       Pandas
# 6            Api  Flask-restx
